# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamedalifaragitiai/Mohamed-Ali-Farag-Projects/blob/main/Image_Representation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # First import the required Python Libraries
#
# > Indented block

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
import skimage

# %%
#!pip install scikit-image --upgrade

# %%
from skimage import img_as_uint

# %%
from skimage.io import imshow, imread

# %%
from skimage.color import rgb2hsv

# %%
from skimage.color import rgb2gray

# %%
arr_1 = np.array([[255,0],[0,255]])
imshow(arr_1, cmap = 'gray')
# Out:
# /usr/local/lib/python3.8/dist-packages/skimage/io/_plugins/matplotlib_plugin.py:150: UserWarning: Low image data range; displaying image with stretched contrast.
#   lo, hi, cmap = _get_display_range(image)

# %%
arr_2 = np.array([[255,0,255],
                  [0,255,0],
                  [255,0,255]])
imshow(arr_2, cmap = 'gray')

# %%
array_spectrum = np.array([np.arange(0,255,17), 
                   np.arange(255,0,-17),
                   np.arange(0,255,17),
                   np.arange(255,0,-17)])

# %%
fig, ax = plt.subplots(1,2, figsize=(12,4))
ax[0].imshow(array_spectrum, cmap = 'gray')
ax[0].set_title('Arange Generation')
ax[1].imshow(array_spectrum.T, cmap = 'gray')
ax[1].set_title('Transpose Generation')
# Out:
# Text(0.5, 1.0, 'Transpose Generation')

# %%
array_colors = np.array([[[255,0,0],
                         [0,255,0],
                         [0,0,255]]])

# %%
imshow(array_colors)

# %%
c = imread('cat.jpg')
imshow(doggo)

# %%
c.shape
# Out:
# (134, 134, 3)

# %%
fig, ax = plt.subplots(1, 3,
                       figsize = (6,4),
                       sharey = True)
ax[0].imshow(c[:, 0:60])
ax[0].set_title('Frist Split')

ax[1].imshow(c[:, 60:90])
ax[1].set_title('Second Split')

ax[2].imshow(c[:,90:134])
ax[2].set_title('Third Split')
# Out:
# Text(0.5, 1.0, 'Third Split')

# %%
imshow(c[60:111, 100:130])

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,4), sharey = True)

ax[0].imshow(c[:, :, 0], cmap= 'Reds')
ax[0].set_title('Red Cat')

ax[1].imshow(c[:, : ,1], cmap='Greens')
ax[1].set_title('Green Cat')

ax[2].imshow(c[:,:,2], cmap = 'Blues')
ax[2].set_title('Blue Cat')
# Out:
# Text(0.5, 1.0, 'Blue Cat')

# %% [markdown]
# Additionally, we can convert the image from RGB (Red, Green, Blue) to HSV (Hue, Saturation, Value).

# %%
cat_hsv = rgb2hsv(c)

# %%
fig, ax = plt.subplots(1,3, figsize=(12, 4), sharey = True)

ax[0].imshow(cat_hsv[:,:,0], cmap = 'hsv')
ax[0].set_title('Hue Version')

ax[1].imshow(cat_hsv[:, :, 1], cmap= 'gray')
ax[1].set_title('Saturation')

ax[2].imshow(cat_hsv[:,:,2],cmap = 'gray')
ax[2].set_title('Value')
# Out:
# Text(0.5, 1.0, 'Value')

# %% [markdown]
# Lastly, we can also convert the image matrix to grayscale. By we transform the image to a simple 2x2 matrix. This allows us to easily filter our image based on each pixel’s relation to a specified value.

# %%
cat_gray = rgb2gray(c)

# %%
fig, ax = plt.subplots(1, 5, figsize=(17,6), sharey = True)
ax[0].imshow(cat_gray, cmap = 'gray')
ax[0].set_title('Gray Scale original')

ax[1].imshow(img_as_uint(cat_gray > 0.25), cmap = 'gray')
ax[1].set_title('Greater than 0.25')

ax[2].imshow(img_as_uint(cat_gray > 0.50), cmap = 'gray')
ax[2].set_title('Greater than 0.50')

ax[3].imshow(img_as_uint(cat_gray > 0.75), cmap = 'gray')
ax[3].set_title('Greater than 0.775')

ax[4].imshow(img_as_uint(cat_gray > np.mean(cat_gray)), cmap = 'gray')
ax[4].set_title('Greater than mean of the image')
# Out:
# Text(0.5, 1.0, 'Greater than mean of the image')

# %% [markdown]
# **Using OpenCv = CV2**

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
cv2.__version__
# Out:
# '4.6.0'

# %%
# The function cv2.imread() is used to read an image.
img_grayscale = cv2.imread('cat.jpg',0)
 
# The function cv2.imshow() is used to display an image in a window.
cv2_imshow(img_grayscale)
# Out:
# <PIL.Image.Image image mode=L size=134x134 at 0x7FBAFA1DDEB0>

# %%
# waitKey() waits for a key press to close the window and 0 specifies indefinite loop
cv2.waitKey(0)
 
# cv2.destroyAllWindows() simply destroys all the windows we created.
cv2.destroyAllWindows()
 
# The function cv2.imwrite() is used to write an image.
cv2.imwrite('grayscale.jpg',img_grayscale)
# Out:
# True

# %%
# Read an image
img_color = cv2.imread('cat.jpg',cv2.IMREAD_COLOR)
img_grayscale = cv2.imread('cat.jpg',cv2.IMREAD_GRAYSCALE)
img_unchanged = cv2.imread('cat.jpg',cv2.IMREAD_UNCHANGED)

# %%
# Read an image
img_color = cv2.imread('cat.jpg',1)
img_grayscale = cv2.imread('cat.jpg',0)
img_unchanged = cv2.imread('cat.jpg',-1)

# %%
#Displays image inside a window
cv2_imshow(img_color)  
cv2_imshow(img_grayscale)
cv2_imshow(img_unchanged)
 
# Waits for a keystroke
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=134x134 at 0x7FBB0692D5E0>
# <PIL.Image.Image image mode=L size=134x134 at 0x7FBAFA201EB0>
# <PIL.Image.Image image mode=RGB size=134x134 at 0x7FBB088EABE0>
# -1

# %% [markdown]
# Writing an Image
# Finally, let’s discuss how to write/save an image into the file directory, using the imwrite() function. Check out its syntax:
#
# imwrite(filename, image).

# %%
cv2.imwrite('cat.jpg',img_grayscale)
# Out:
# True

# %% [markdown]
# **Translation of Images using OpenCV**

# %% [markdown]
# In computer vision, translation of an image means shifting it by a specified number of pixels, along the x and y axes. Let the pixels by which the image needs to shifted be tx and ty. Then you can define a translation matrix M:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# read the image 
image = cv2.imread('cat.jpg')
# get the width and height of the image
height, width = image.shape[:2]

# %%
# get tx and ty values for translation
# you can specify any value of your choice
tx, ty = width / 4, height / 4
 
# create the translation matrix using tx and ty, it is a NumPy array 
translation_matrix = np.array([
    [1, 0, tx],
    [0, 1, ty]
], dtype=np.float32)

# %%
# apply the translation to the image
translated_image = cv2.warpAffine(src=image, M=translation_matrix, dsize=(width, height))

# %%
# display the original and the Translated images
cv2_imshow( translated_image)
cv2_imshow(image)
cv2.waitKey(0)
# save the translated image to disk
cv2.imwrite('translated_image.jpg', translated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=134x134 at 0x7FBAFA206640>
# <PIL.Image.Image image mode=RGB size=134x134 at 0x7FBAFA206A60>
# True

# %% [markdown]
# **Image Rotation using OpenCV**

# %% [markdown]
# You can rotate an image by a certain angle \theta by defining a transformation matrix M. This matrix is usually of the form:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Reading the image
image = cv2.imread('cat.jpg')

# %%
# Dividing height and width by 2 to get the center of the image
height, width = image.shape[:2]
center = (width/2, height/2)

# %%
# the above center is the center of rotation axis
# use cv2.getRotationMatrix2D() to get the rotation matrix
rotate_matrix = cv2.getRotationMatrix2D(center=center, angle=45, scale=1)

# %%
# Rotate the image using cv2.warpAffine
rotated_image = cv2.warpAffine(src=image, M=rotate_matrix, dsize=(width, height))

# %%
# visualize the original and the rotated image
cv2_imshow( image)
# Out:
# <PIL.Image.Image image mode=RGB size=134x134 at 0x7FBB06936940>

# %%
cv2_imshow( rotated_image)
# wait indefinitely, press any key on keyboard to exit
cv2.waitKey(0)
# write the output, the rotated image to disk
cv2.imwrite('rotated_image.jpg', rotated_image)
# Out:
# <PIL.Image.Image image mode=RGB size=134x134 at 0x7FBAFA2011C0>
# True

# %% [markdown]
# **Image scaling** is the process of resizing a digital image. Scaling down an image makes it smaller while scaling up an image makes it larger. Both raster graphics and vector graphics can be scaled, but they produce different results.

# %%
# Reading the image
img = cv2.imread('cat.jpg')
 
print('Original Dimensions : ',img.shape)
 
scale_percent = 60 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)
  
# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
 
print('Resized Dimensions : ',resized.shape)
 
cv2_imshow( resized)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (134, 134, 3)
# Resized Dimensions :  (80, 80, 3)
# <PIL.Image.Image image mode=RGB size=80x80 at 0x7FBAFA206100>

# %% [markdown]
# **Cropping Using OpenCV**

# %%
img=cv2.imread('cat.jpg')
 
# Prints Dimensions of the image
print(img.shape) 
 
# Display the image
cv2_imshow( img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (134, 134, 3)
# <PIL.Image.Image image mode=RGB size=134x134 at 0x7FBAFA2044F0>

# %%
cropped_image = img[40:80, 90:100] # Slicing to crop the image
 
# Display the cropped image
cv2_imshow(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=10x40 at 0x7FBAFA201AC0>
